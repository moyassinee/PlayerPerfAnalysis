# %%
import pandas as pd
import numpy as np
import soccerdata as sd
import warnings
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

import sys
import os
warnings.filterwarnings("ignore")

# Add project root to Python path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

from functions import *

season = ["2024-25","2025-26"]
fbref = sd.FBref("Big 5 European Leagues Combined", season)
# Out:
# [03/29/26 13:08:27] INFO     Saving cached data to C:\Users\Yassine\soccerdata\data\FBref            ]8;id=769265;file://c:\Python310\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=914593;file://c:\Python310\lib\site-packages\soccerdata\_common.py#263\263]8;;\

# %%
# Out:
# 302

# %% [markdown]
# ## Explore Data

# %%
#import functions from functions.py
result_df = pd.DataFrame()
temp_df = pd.DataFrame()

for i in ["shooting", "passing","defense", "possession","goal_shot_creation"]:
    globals()[f"{i}_df"] = read_players_data(fbref, i)
    
#forwards = df[df['pos_'].isin(['FW', 'FW,MF'])]

shooting_df = shooting_df[shooting_df['pos_'].isin(['FW', 'FW,MF'])]
shooting_df = shooting_df[shooting_df['90s_'] >= 10]

passing_df = passing_df[passing_df['pos_'].isin(['FW', 'FW,MF'])]
passing_df = passing_df[passing_df['90s_'] >= 10]

defense_df = defense_df[defense_df['pos_'].isin(['FW', 'FW,MF'])]
defense_df = defense_df[defense_df['90s_'] >= 10]

possession_df = possession_df[possession_df['pos_'].isin(['FW', 'FW,MF'])]
possession_df = possession_df[possession_df['90s_'] >= 10]


df = shooting_df.merge(passing_df, on=['player_', 'season_', 'team_'], how='outer', suffixes=('', '_sh'))
df = df.merge(defense_df, on=['player_', 'season_', 'team_'], how='outer', suffixes=('', '_pos'))
df = df.merge(possession_df, on=['player_', 'season_', 'team_'], how='outer', suffixes=('', '_gca'))


cumulative_cols = ["90s_","Standard_Sh/90", "Standard_SoT/90","Expected_xG", 'Total_Cmp', "Total_Att", "Total_PrgDist",
            "Ast_", "xAG_", "Expected_xA", "KP_","1/3_","PPA_","CrsPA_","PrgP_",
            "Tackles_Tkl","Tackles_TklW","Take-Ons_Att","Take-Ons_Succ","Carries_PrgDist",	"Carries_PrgC",	"Carries_1/3"]

# Keep the most recent team & age for display purposes
meta_cols = ["player_", "team_", "age_", "league_", "pos_"]

most_recent = (
    df.sort_values("season_", ascending=False)
    .groupby("player_")[["team_", "age_", "league_", "pos_"]]
    .first()
    
)

df_agg = (
    df.groupby("player_")[cumulative_cols]
    .sum(min_count=1)   # NaN if a player has no data at all
    .reset_index()
    .merge(most_recent, on="player_", how="left")
)

# ── 5. FILTER: min 10 90s across both seasons combined ──────────────────
df_agg = df_agg[df_agg["90s_"] >= 20]


feat_90 = [c for c in cumulative_cols if c not in ["90s_","Standard_Sh/90", "Standard_SoT/90"]]
df_agg[feat_90] = df_agg[feat_90].div(df_agg["90s_"], axis=0)



features = ["Standard_Sh/90", "Standard_SoT/90", "Expected_xG", 'Total_Cmp', "Total_Att", "Total_PrgDist",
            "Ast_", "xAG_", "Expected_xA", "KP_","1/3_","PPA_","CrsPA_","PrgP_",
            "Tackles_Tkl","Tackles_TklW","Take-Ons_Att","Take-Ons_Succ","Carries_PrgDist",	"Carries_PrgC",	"Carries_1/3"]

# Handle missing values (simple imputation with median)
X = df_agg[features]
X = df_agg[features].fillna(X.median())

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

salah_pos = np.where(df_agg['player_'] == 'Mohamed Salah')[0][0]
salah_vector = X_scaled[salah_pos].reshape(1, -1)



similarities = cosine_similarity(salah_vector, X_scaled)[0]
df_agg['similarity_score'] = similarities


similar_players = (
    df_agg[df_agg['player_'] != 'Mohamed Salah']
    .sort_values('similarity_score', ascending=False)
)

similar_players[['player_','team_', 'age_', 'similarity_score']].head(10)
# Out:
#              player_            team_    age_  similarity_score
# 240    Michael Olise    Bayern Munich  24-013          0.827635
# 330    Son Heung-min        Tottenham      32          0.799135
# 48   Bradley Barcola        Paris S-G      21          0.796970
# 57       Bukayo Saka          Arsenal  24-111          0.775915
# 223  Marcus Rashford        Barcelona  28-055          0.770654
# 179   Julián Álvarez  Atlético Madrid  25-328          0.756396
# 296         Raphinha        Barcelona      27          0.751904
# 292      Rafael Leão            Milan      25          0.748810
# 273    Omar Marmoush  Manchester City      25          0.724155
# 70        Cody Gakpo        Liverpool  26-232          0.721189

# %%
# 2. Use it in your 'Young Talent' filter
similar_players_young = similar_players[
    (similar_players['age_'] <= 23) & 
    (similar_players['league_'] != 'Premier League')
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 3
#       1 # 2. Use it in your 'Young Talent' filter
#       2 similar_players_young = similar_players[
# ----> 3     (similar_players['age_'] <= 23) &
#       4     (similar_players['league_'] != 'Premier League')
#       5 ]
#
# File c:\Python310\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Python310\lib\site-packages\pandas\core\arraylike.py:52, in OpsMixin.__le__(self, other)
#      50 @unpack_zerodim_and_defer("__le__")
#      51 def __le__(self, other):
# ---> 52     return self._cmp_method(other, operator.le)
#
# ...
